# %%
# %run ./Includes/Copy-Datasets

# %%
# %sql
drop table if exists orders_updates;

# %%
dbutils.fs.rm(f"{dataset_bookstore}/orders-checkpoint", True)

# %%
files = dbutils.fs.ls(f"{dataset_bookstore}/orders-raw")
display(files)

# %%
(spark.readStream.format("cloudFiles").option("cloudFiles.format", "parquet").option("cloudFiles.schemaLocation", f"{dataset_bookstore}/orders-checkpoint").load(f"{dataset_bookstore}/orders-raw").writeStream.option("checkpointLocation", f"{dataset_bookstore}/orders-checkpoint").table("orders_updates"))b

# %%
# %sql
select * from orders_updates;

# %%
load_new_data()

# %%
# %sql
select * from orders_updates;

# %%
# %sql
describe history orders_updates;
